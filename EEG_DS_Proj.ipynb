# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report

# %%
data = pd.read_csv('/content/drive/My Drive/emotions.csv')

# %%
data.head()
# Out:
#    # mean_0_a  mean_1_a  mean_2_a  mean_3_a  mean_4_a  mean_d_0_a  mean_d_1_a  \
# 0        4.62      30.3    -356.0      15.6      26.3       1.070       0.411
# 1       28.80      33.1      32.0      25.8      22.8       6.550       1.680
# 2        8.90      29.4    -416.0      16.7      23.7      79.900       3.360
# 3       14.90      31.6    -143.0      19.8      24.3      -0.584      -0.284
# 4       28.30      31.3      45.2      27.3      24.5      34.800      -5.790
#
#    mean_d_2_a  mean_d_3_a  mean_d_4_a  ...  fft_741_b  fft_742_b  fft_743_b  \
# 0      -15.70        2.06        3.15  ...       23.5       20.3       20.3
# 1        2.88        3.83       -4.82  ...      -23.3      -21.8      -21.8
# 2       90.20       89.90        2.03  ...      462.0     -233.0     -233.0
# 3        8.82        2.30       -1.97  ...      299.0     -243.0     -243.0
# 4        3.06       41.40        5.52  ...       12.0       38.1       38.1
#
# ...

# %%
data.shape
# Out:
# (2132, 2549)

# %%
for col in data.columns:
    if(data[col].isnull().sum()>0):
        print(col)

# %% [markdown]
# # ***Visualization of the Dataset from fft_0_b to fft_749_b collums dataset EEG readings***

# %%
# here we will se the data stats plotted
sample = data.loc[0, 'fft_0_b':'fft_749_b']
plt.figure(figsize=(16, 10))
plt.plot(range(len(sample)), sample)
plt.title('Feautures fft_0_b through fft_749_b')
plt.show()

# %%
data['label'].value_counts()
# Out:
# NEUTRAL     716
# NEGATIVE    708
# POSITIVE    708
# Name: label, dtype: int64

# %%
label_mapping = {'NEGATIVE': 0, 'NEUTRAL': 1, 'POSITIVE': 2}

# %%
def preprocess_inputs(df):
  df = df.copy()
    
  df['label'] = df['label'].replace(label_mapping)
    
  y = df['label'].copy()
  X = df.drop('label', axis=1).copy()
    
  X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, random_state=123)
    
  return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = preprocess_inputs(data)

# %%
X_train
# Out:
#       # mean_0_a  mean_1_a  mean_2_a  mean_3_a  mean_4_a  mean_d_0_a  \
# 993       14.400      29.7    -112.0     18.50      22.9    -3.63000
# 1851      13.700      22.8      21.5      8.40      27.1     3.27000
# 1253      -0.765      24.7    -578.0     11.90      27.9    -1.44000
# 1228      28.200      32.6      32.1     30.30      24.6    -0.00524
# 1461      31.900      31.0      34.4     30.80      24.0    -4.74000
# ...          ...       ...       ...       ...       ...         ...
# 1593       6.820      32.9    -741.0     32.60      27.0    -0.41300
# 1147      31.500      32.1      31.3     28.80      25.0     5.32000
# 1766     -11.800      26.3    -828.0      7.68      23.3    13.10000
# 1122      27.600      32.2      28.8     25.60      24.1    -6.94000
# 1346      13.700      29.6    -204.0     11.40      29.9     4.50000
#
#       mean_d_1_a  mean_d_2_a  mean_d_3_a  mean_d_4_a  ...  fft_740_b  \
# ...

# %% [markdown]
# # ***METHOD-1 Training our Model using Regular Neural Network with 2 Hidden Layers and mesuring accuracy***

# %%
inputs = tf.keras.Input(shape=(X_train.shape[1],))

x = tf.keras.layers.Dense(64, activation='relu')(inputs)
x = tf.keras.layers.Dense(64, activation='relu')(x)

outputs = tf.keras.layers.Dense(3, activation='softmax')(x)

model = tf.keras.Model(inputs, outputs=outputs)
print(model.summary())
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_2 (InputLayer)        [(None, 2548)]            0
#
#  dense_3 (Dense)             (None, 64)                163136
#
#  dense_4 (Dense)             (None, 64)                4160
#
#  dense_5 (Dense)             (None, 3)                 195
#
# ...
# Total params: 167,491
# Trainable params: 167,491
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
model.compile(
    optimizer='SGD',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

history = model.fit(
    X_train,
    y_train,
    validation_split=0.2,
    batch_size=32,
    epochs=50,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(
            monitor='val_loss',
            patience=5,
            restore_best_weights=True
        )
    ]
)
# Out:
# Epoch 1/50
# 38/38 [==============================] - 1s 13ms/step - loss: nan - accuracy: 0.3529 - val_loss: nan - val_accuracy: 0.3311
# Epoch 2/50
# 38/38 [==============================] - 0s 6ms/step - loss: nan - accuracy: 0.3420 - val_loss: nan - val_accuracy: 0.3311
# Epoch 3/50
# 38/38 [==============================] - 0s 7ms/step - loss: nan - accuracy: 0.3420 - val_loss: nan - val_accuracy: 0.3311
# Epoch 4/50
# 38/38 [==============================] - 0s 8ms/step - loss: nan - accuracy: 0.3420 - val_loss: nan - val_accuracy: 0.3311
# Epoch 5/50
# 38/38 [==============================] - 0s 12ms/step - loss: nan - accuracy: 0.3420 - val_loss: nan - val_accuracy: 0.3311

# %%
model_acc = model.evaluate(X_test, y_test, verbose=0)[1]
print("Test Accuracy: {:.3f}%".format(model_acc * 100))
# Out:
# Test Accuracy: 31.406%

# %%
plt.bar(['Adam','Adgrad','SGD','RMsprop'], [65.156, 50.652, 31.406, 70.156])
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# # **METHOD-2 Training our Model using Recurrent Neural Network and mesuring accuracy**

# %%
# inputs = tf.keras.Input(shape=(X_train.shape[1],))

# expand_dims = tf.expand_dims(inputs, axis=2)
# gru = tf.keras.layers.GRU(256, return_sequences=True)(expand_dims)
# flatten = tf.keras.layers.Flatten()(gru)
# outputs = tf.keras.layers.Dense(3, activation='softmax')(flatten)

# model = tf.keras.Model(inputs=inputs, outputs=outputs)
# print(model.summary())

# %% [markdown]
# # ***How our RNN will work***

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# model.compile(
#     optimizer='SGD',
#     loss='sparse_categorical_crossentropy',
#     metrics=['accuracy']
# )

# history = model.fit(
#     X_train,
#     y_train,
#     validation_split=0.2,
#     batch_size=50,
#     epochs=150,
#     callbacks=[
#         tf.keras.callbacks.EarlyStopping(
#             monitor='val_loss',
#             patience=5,
#             restore_best_weights=True
#         )
#     ]
# )

# %%
# model_acc = model.evaluate(X_test, y_test, verbose=0)[1]
# print("Test Accuracy: {:.3f}%".format(model_acc * 100))

# %%
y_pred = np.array(list(map(lambda x: np.argmax(x), model.predict(X_test))))

cm = confusion_matrix(y_test, y_pred)
clr = classification_report(y_test, y_pred, target_names=label_mapping.keys())

plt.figure(figsize=(8, 8))
sns.heatmap(cm, annot=True, vmin=0, fmt='g', cbar=False, cmap='Blues')
plt.xticks(np.arange(3) + 0.5, label_mapping.keys())
plt.yticks(np.arange(3) + 0.5, label_mapping.keys())
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

print("Classification Report:\n----------------------\n", clr)
# Out:
# Classification Report:
# ----------------------
#                precision    recall  f1-score   support
#
#     NEGATIVE       0.78      0.89      0.83       201
#      NEUTRAL       0.74      0.74      0.74       231
#     POSITIVE       0.56      0.48      0.51       208
#
#     accuracy                           0.70       640
#    macro avg       0.69      0.70      0.69       640
# weighted avg       0.69      0.70      0.69       640
